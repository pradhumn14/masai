# %%
greeting = "!     Hello  there!   "

# %%
print(((greeting)))
# Out:
# !     Hello  there!

# %%
num1 = 10
num2 = 20

# %%
sum_result = num1 + num2
print("Sum:", sum_result)
# Out:
# Sum: 30

# %%
from src.utils import add

result = add(num1, num2)
print("Result from utils.add:", result)
# Out:
# Result from utils.add: 30
